# %% [markdown]
# # Prompt Engineering: Use OpenAI to Analyze Twitter Data
# This is a simple tutorial teaching prompt engineering basics and analyzing Twitter data with OpenAI large language models (LLM).
# Please purchase an [OpenAI API](https://openai.com/index/openai-api/) and store it in a safe place. This tutorial uses [AWS Secretes Manager](https://aws.amazon.com/secrets-manager/) to store the API keys.

# %% [markdown]
# ## Large Language Model Basics
# LLM repeatable predicts the next world using supervised learning. To predict the following sentence:
#
# `Learning data science in the cloud with AI`
#
# A model needs to learn to predict the following steps:
#
# |Input|Output|
# |:---|---|
# |Learning data science |in |
# |Learning data science in |the |
# |Learning data science in the |cloud |
# |Learning data science in the cloud |with |
# |Learning data science in the cloud with |AI|
#
# To train an LLM model:
# 1. Training a base LLM model on a large amount of training data to predict the next word
# 2. Fine-tune on examples where outputs follow instructions in the input
# 3. Human rates quality of different LLM outputs
# 4. Tune LLM to generate outputs with higher rates using RLHF (Reinforcement learning from human feedback)

# %% [markdown]
# ## Set up OpenAI Models

# %% [markdown]
# Load the API keys with AWS Secrets Manage Function

# %%
import boto3
from botocore.exceptions import ClientError
import json

def get_secret(secret_name):
    region_name = "us-east-1"

    # Create a Secrets Manager client
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name
    )

    try:
        get_secret_value_response = client.get_secret_value(
            SecretId=secret_name
        )
    except ClientError as e:
        raise e

    secret = get_secret_value_response['SecretString']
    
    return json.loads(secret)

# %% [markdown]
# ## Install Python libraries.
#
# - pymongo: manage the MongoDB database
# - openai: call the OpenAI APIs.

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.75.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.8.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (2.11.0)
# Requirement already satisfied: sniffio in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Downloading openai-1.75.0-py3-none-any.whl (646 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.0/647.0 kB 37.2 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (352 kB)
# Installing collected packages: jiter, distro, openai
# Successfully installed distro-1.9.0 jiter-0.9.0 openai-1.75.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (4.12.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pymongo) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Load the OpenAI API key and define a `openai_help` function.

# %%
from openai import OpenAI

openai_api_key  = get_secret('openai')['api_key']
client = OpenAI(api_key=openai_api_key)
model = 'gpt-4o'
temperature = 0

def openai_help(messages, model=model, temperature =temperature ):
    messages = messages
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature

    )
    return response.choices[0].message.content

# %% [markdown]
# Temperature:
# - Low temperature: always choose the most likely response, reliable, predictable responses
# - High temperature: diverse responses, more creative responses
#
# Tokens and Models:
# - LLM predicts tokens, which are commonly occurring sequences of characters.
# - One token is about four characters in English, and 100 tokens are roughly 75 words. Check [token estimate](https://platform.openai.com/tokenizer).
# - Different models can process various amounts of tokens at different performance levels and costs. Check [OpenAI models](https://platform.openai.com/docs/models) for more details.
#
# Roles:
# - system: specify the overall tone or behavior of the assistant
# - user: instruction given to the LLM
# - assistant: LLM responded content, we also can provide content in few-shot promoting or histories of conversations

# %% [markdown]
# A simple example using [gtp-4o](https://platform.openai.com/docs/models/gpt-4o) and temperature 0.

# %%
messages = [{"role": "user", "content": "What is the capital of USA"}]

print(openai_help(messages))
# Out:
# The capital of the United States is Washington, D.C.

# %% [markdown]
# Add a system message asking LLM to act as a high school teacher with different temperatures.

# %%
messages = [
    {"role": "system", "content": "use tone as a high school teacher"},
    {"role": "user", "content": "What is the capital of USA"}
    ]

print(openai_help(messages, temperature = 0.8))
# Out:
# The capital of the United States is Washington, D.C. Make sure you remember this, as it's a commonly asked question in geography!

# %% [markdown]
# Add assistant messages to teach LLM what `##` is.

# %%
messages = [
    {"role": "user", "content": "What is 1##1"},
    {"role": "assistant", "content": "it is 11"},
    {"role": "user", "content": "What is 2##2"},
    {"role": "assistant", "content": "it is 22"},
    {"role": "user", "content": "What is 3##3"},
    ]
print(openai_help(messages))
# Out:
# The expression "3##3" does not have a standard mathematical interpretation. If you are referring to a specific operation or notation, please provide more context. If you are following a pattern similar to previous examples where "1##1" was interpreted as "11" and "2##2" as "22," then "3##3" would be "33."

# %% [markdown]
# ## Prompt Engineering Principles
# - Use delimiters to separate different parts of a prompt to provide clear instructions and prevent prompt injections.
# - Structure outputs in JSON documents or other formats to use the outputs in subsequent steps
# - Few-shot promoting: provide successful examples of a task and then ask the model to perform a similar task.
# - Chain of thought reasoning: request a series of reasoning steps in prompts to help the model achieve correct answers
# - Chain of prompts: split a task into multiple prompts where each prompt can focus on a sub-task at a time and take different actions at different stages. It saves tokens, is easier to test, can involve human input, or use external tools.
# - Interactive process
#   1. Try something first
#   2. Analyses the result, identify errors, and redefine the prompt
#   3. Test the prompts with different datasets

# %% [markdown]
# An example using delimiters, structured output and few-shot promoting:

# %%
delimiter = '###'
sentence1 = 'I love cat.'
sentence2 = 'I love dog.'
messages = [
    {"role": "system", "content": f"""analyze the sentiment in a sentence delimitered by {delimiter},
                                     return the result as a JSON document"""},
    {"role": "user", "content": f"{delimiter}{sentence1}{delimiter}"},
    {"role": "assistant", "content": "{sentiment:positive}"},
    {"role": "user", "content": f"{delimiter}{sentence2}{delimiter}"}
    ]

print(openai_help(messages))
# Out:
# { "sentiment": "positive" }

# %% [markdown]
# ## Analyze Twitter data

# %% [markdown]
# ### Connect to the MongoDB cluster

# %%
import pymongo
from pymongo import MongoClient
mongodb_connect = get_secret('mongodb')['connection_string']

mongo_client = MongoClient(mongodb_connect)
db = mongo_client.demo # use or create a database named demo
tweet_collection = db.tweet_collection #use or create a collection named tweet_collection
tweet_collection.create_index([("tweet.id", pymongo.ASCENDING)],unique = True) # make sure the collected tweets are unique
# Out:
# 'tweet.id_1'

# %% [markdown]
# ### Extract Tweets

# %%
filter={

    
}
project={
    'tweet.text': 1, 
    'tweet.id': 1
}
#rename the client to mongo_client
result = mongo_client['demo']['tweet_collection'].find(
  filter=filter,
  projection=project
)

# %%
tweet_data = []
for tweet in result:
    tweet_data.append(tweet['tweet']['text'])

# %%
print('Number of tweets: ',len(tweet_data))
# Out:
# Number of tweets:  93

# %% [markdown]
# ### Summarization
# - Analyze election tweets with delimiters
# - Change the size of the summarization
# - Summarize tweets and focus on different perspectives.

# %%
messages = [
    {"role": "system", "content": f"""provide a brief summary of the tweets delimited by {delimiter}"""},
    {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter}"},
    ]

print(openai_help(messages))
# Out:
# The tweets primarily discuss various aspects and applications of generative AI. They highlight its integration in fields like IoT solutions, mobile and web development, and its role in enhancing weather forecasting and clinical data analysis. There are mentions of events and collaborations, such as Dubai AI Week 2025 and partnerships with AWS. Some tweets express skepticism or criticism of generative AI, particularly in art and journalism, while others emphasize its transformative potential in HR and marketing. Additionally, there are discussions about the ethical implications and the need for regulation in the use of generative AI.

# %%
messages = [
    {"role": "system", "content": f"""provide a brief summary of the tweets delimited by {delimiter},
                                    limit the summary to 20 words"""},
    {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter}"},
    ]

print(openai_help(messages))
# Out:
# The tweets discuss generative AI's impact on various fields, including art, technology, and business, highlighting both opportunities and controversies.

# %%
messages = [
    {"role": "system", "content": f"""provide a brief summary of the tweets delimited by {delimiter},
                                    focus on how people discuss AI,
                                    limit the summary to 50 words"""},
    {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter}"},
    ]

print(openai_help(messages))
# Out:
# People discuss AI with a focus on generative AI's impact across various fields, including art, music, and business. Opinions are mixed, with some praising its efficiency and potential, while others criticize its ethical implications and lack of creativity. Calls for regulation and ethical considerations are prevalent.

# %% [markdown]
# ### Moderation
# - Iterate each tweet and use the [moeration endpoint](https://platform.openai.com/docs/api-reference/moderations) to identify flagged tweets
# - Print flagged tweets

# %%
def flag_help(tweet):
    response = client.moderations.create(
        model="omni-moderation-latest",
        input=tweet)

    if response.results[0].flagged:
        print('===')
        cat_dict = response.results[0].categories.to_dict()
        for cat in cat_dict.keys():
            if cat_dict.get(cat):
                print (cat)
                print(tweet)

# %%
for tweet in tweet_data:
    flag_help(tweet)
# Out:
# ===
# harassment
# @nic__carter @d_fins I think you misinterpret what people say. Ai is fine, generative Ai “art” that steals others work to mold it to what you want? That’s retarded lmao. You use absolutely no skill and your “art” (it’s not art cause it has no emotion) is quite literally jsut not art by definition
# ===
# harassment
# @nic__carter I'm more right leaning and fuck you and anyone else who supports the use of generative AI.
# ===
# harassment
# RT @clevelandy_: Fuck everyone who uses generative ai to create images for their fanfiction. I am better than you.
# ===
# harassment
# RT @clevelandy_: Fuck everyone who uses generative ai to create images for their fanfiction. I am better than you.
# ===
# harassment
# what's sad about ai artists is their clear lack of imagination. I've seen people make use of generative ai to produce really breathtaking art, but these people are the few. The larger majority of ai artists will just bastardize someone else art just like this below. https://t.co/laeHuR2U90
# ===
# harassment
# RT @clevelandy_: Fuck everyone who uses generative ai to create images for their fanfiction. I am better than you.
# ===
# harassment
# https://t.co/GuGOwzjAvP
#
# https://t.co/C3UxQbIeJ1
#
# https://t.co/7SPApk2WBj
#
# “YOU” are stealing from REAL writers and artists. AND you’re killing the planet. You should be ashamed of yourself
# ===
# harassment
# Fuck everyone who uses generative ai to create images for their fanfiction. I am better than you. https://t.co/7DctyISPuw

# %% [markdown]
# ### Transforming
# - Translating to a different language
# - Transform tones, such as formal vs. informal.

# %%
for tweet in tweet_data:
    messages = [
        {"role": "system", "content": f"""translate the tweets delimited by {delimiter} into Chinese"""},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]

    print(openai_help(messages).strip(delimiter))
# Out:
# 我们专注于： • 物联网解决方案 • 生成式AI集成 • 移动应用开发 • 网站开发 • 大学项目和MVP原型 快速、可靠且经济实惠！ 让我们一起打造一些很棒的东西。 了解更多：https://t.co/DXZqtPhy42 #与我们一起创新
# RT @jradoff: 人工智能直播——主持人Jon Radoff（Beamable）欢迎Scenario的Emmanuel de Maistre，共同探讨创作者如何……
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# RT @DDNintelligence: DDN在Gartner最新的必读报告中被提及：
# “CTO的生成式AI技术景观指南” 👇
#
# 为什么这…
# RT @jradoff: 人工智能直播——主持人Jon Radoff（Beamable）邀请Scenario的Emmanuel de Maistre探讨创作者如何……
# 转发 @mdancho84: “生成式AI数据科学家”的崛起
#
# 这就是正在发生的事情：https://t.co/SBtpyKvJWY
# 大家好，我亲爱的天气爱好者和科技迷们！🌤️💻 这里是AisanDoll，今天我们要探讨一个和我的推特动态一样难以预测的话题——天气预报！但别担心，我有一个秘密武器：生成式AI。没错，就是那个
# 完成了第5讲！✨刚刚实现了我的第一个RAG系统！学习如何将文档检索与生成式AI结合。很高兴看到这如何减少幻觉并改善上下文处理！#GenAI #RAG #机器学习 #chaiaurcode
# @piyushgarg_dev
#
# @Hiteshdotcom https://t.co/NjuEv72emK
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# 我还注意到你们持续未能解释为何未能遵循基本的新闻标准，使用生成式AI制作图像，而不是使用现有的库存图像等问题。
# @nic__carter @d_fins 我认为你误解了人们所说的话。人工智能没问题，但生成式人工智能“艺术”窃取他人的作品来塑造成你想要的样子？那太愚蠢了，哈哈。你完全不需要任何技巧，而你的“艺术”（这不是艺术，因为它没有情感）从定义上来说根本就不是艺术。
# RT @jradoff: 人工智能直播——主持人Jon Radoff（Beamable）欢迎Scenario的Emmanuel de Maistre，共同探讨创作者如何……
# RT @DDNintelligence: DDN在Gartner最新的必读报告中被提及：
# “CTO的生成式AI技术景观指南” 👇
#
# 为什么这…
# @SF_22as 当我过去经常发布粉丝翻译作品时，AI工具在清理同人画方面非常出色，原本需要30-60分钟的清理工作现在只需5-10分钟，而且效果更好。
#
# 此外，我制作的许多无耳动图也使用了生成填充技术。https://t.co/1i7KGoaKZk
# RT @ZarkLab: Zark Lab 正在与 @SuiNetwork 合作推出一个区块链原生的基础模型。
#
# 我们的生成式 AI 平台有助于构建…
# 技术企业家的崛起：生成式人工智能时代的愿景 https://t.co/b3nn9HDnJV https://t.co/nW9mJi3SrE
# @nic__carter 我比较偏右，去你的，去所有支持使用生成式AI的人。
# @GainsAssociates @Brcevik @Gamenessapp #Gameness 将如何发展以支持下一代 AI，例如生成式或对话式 AI？
# 专家呼吁制定本地生成式人工智能法律 - 台北时报 https://t.co/64S3CBmYI0 #生成式AI #GenAI #AI
# Quantiphi 的企业级生成式 AI 平台 baioniq 荣获 2025 年 AI 卓越奖 ... https://t.co/cA5TcRCpXj #GenerativeAI #GenAI #AI
# Quantiphi 的企业级生成式 AI 平台 baioniq 荣获 2025 年 AI 卓越奖 ... https://t.co/9B4rqob0rw #GenerativeAI #GenAI #AI
# Quantiphi 的企业级生成式 AI 平台 baioniq 荣获 2025 年 AI 卓越奖 ... https://t.co/jnGb4kVNg7 #GenerativeAI #GenAI #AI
# Clario与AWS合作，通过生成式AI在临床数据分析中突破新界限 https://t.co/fMKi6sVrnh #生成式AI #GenAI #AI
# 迪拜人工智能周2025将举办全球最大生成式人工智能锦标赛，奖金为27.2万美元 https://t.co/Sn9VghMMOp #生成式AI #GenAI #AI
# Adobe 的照片生成扩展工具和 AI 艺术一样糟糕吗？
# @PunkyBrewstuh @ArsenBalls 这里有一个让你开始。https://t.co/tsXboP79yZ
# RT @AMD: 生成式人工智能变得更好更快了。介绍一下 Amuse 3.0，由 AMD 优化模型与 @StabilityAI 共同开发…
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# RT @jradoff: 人工智能直播——主持人Jon Radoff（Beamable）邀请Scenario的Emmanuel de Maistre探讨创作者如何……
# 转发 @carlos_joseph: 教师担心学生使用人工智能，但他们自己却很喜欢。教育工作者越来越多地使用生成式人工智能……
# RT @jradoff: 人工智能直播——主持人Jon Radoff（Beamable）欢迎Scenario的Emmanuel de Maistre，共同探讨创作者如何……
# RT @onionigirigirii: 我强烈建议大家去看ajar的视频，他用简单易懂的语言解释了这个问题的缺点，让每个人都能理解……
# 世界领先组织的真实生成式人工智能用例 | Google Cloud 博客 https://t.co/aWJzXOFWQO
# @queenathenah 那些一概不喜欢人工智能的人要么对其没有充分了解，要么认为所有人工智能都是生成式的。你说得很对——需要对人工智能的使用方式和原因进行大规模的监管，而且越早越好。
# @Sugenspice @RLoompaskettee 我知道这不是一个数字音频工作站，我是说那个人说话的方式就像他在用一个数字音频工作站（人们通常会在讨论数字音频工作站时说“我用这个你用那个”），但其实不是。我不太喜欢大多数AI生成的音乐（除非你自己制作训练材料或类似的东西）。
# RT @clevelandy_: 去他妈的所有使用生成式AI为他们的同人小说创作图像的人。我比你们强。
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# ⚡️ 利用生成式#AI塑造营销的未来：通过#Google的开源MarTech解决方案解锁新可能性
#
# https://t.co/tXufEuEERx
# RT @Unite4Copyright: “大规模未经授权使用受#版权保护的作品来训练[AI]模型，这些模型生成的材料取代了……”
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# RT @clevelandy_: 去他妈的那些使用生成式AI为他们的同人小说创作图像的人。我比你们强。
# RT @alanxtruc: 摄影与人工智能：富有成效的紧张关系
# 今天法国时间下午5点发布
#
# 提供英文和法文版本
# （两封独立的邮件）
#
# https:/…
# @Touchcast 刚刚以5亿美元被出售。我厌恶他们的“解决方案”，如果我必须通过一个没有灵魂的生成式AI化身来进行交易或学习，我会选择其他地方。科技大佬们认为人们*想要*这个。我们不想。只有高管层才想要。
# 关于AI艺术家令人感到悲哀的是他们明显缺乏想象力。我见过有人利用生成式AI创作出真正令人惊叹的艺术，但这样的人只是少数。大多数AI艺术家只会像下面这样糟蹋别人的艺术。https://t.co/laeHuR2U90
#  @ass_wiper3000 @Jcbl3ach @McCallaPE @GrossRoth @suchnerve 我的意思是，反AI的人群或多或少反对AI的一切（尽管更多是关于生成式AI），所以McCalla不得不说出来，这很有道理。
# RT @jradoff: 人工智能直播——主持人Jon Radoff（Beamable）邀请Scenario的Emmanuel de Maistre探讨创作者如何……
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# 转发 @clevelandy_：去他的所有使用生成式AI为他们的同人小说创作图像的人。我比你们强。
# 如果我们足够烦人，就不会有如此巨大的对生成式AI的支持。我们中很多人甚至没有达到足够烦人的程度，去谈论那些假装成AI、每天只赚几分钱的人类劳动剥削问题。
#
# 在生成式AI方面要更烦人一点。https://t.co/KIqOG1eQSi
# RT @jradoff: 人工智能直播——主持人Jon Radoff（Beamable）邀请Scenario的Emmanuel de Maistre探讨创作者如何……
# 通过DTC的成员主导#DigitalTwin测试平台推动数字工程的未来！使用最佳实践、关键绩效指标和生成式AI支持集成进行协作、测试和部署数字孪生。今天就开始：https://t.co/H78e3NCeF9 https://t.co/6JuRzkDIf5
# @KnightlyGamez @Rythayze @PnishdMythMason 太好了，你的观点是什么？当你向生成式AI系统添加一张图片并将关键词与其关联时，它就进入了系统，可以根据关键词进行变形。看起来你似乎不理解这个过程的基本原理......
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# RT @EZE3D: 当有人进来说类似“我等不及看你丢掉工作然后学到……”这样的话时，总是既可笑又可悲。
# 转发 @Manny5916568446: 有没有想过是什么真正驱动了ChatGPT、Midjourney和Gemini？🤔 揭开生成式AI背后的魔力，最终……
# RT @WhiteHatCereal: @RyanMattaMedia 我一点也不惊讶。
#
# 这是原因。
#
# 如今大多数生成式AI都在保护诊断统计数据…
# 令人惊讶的是，这个所谓的生成式AI如此强大，但在发送大约200封个人邮件时却毫无用处，我不得不逐一亲自撰写每一封。
# RT @onionigirigirii: 我强烈建议大家去看ajar的视频，他用简单易懂的语言解释了这个问题的缺点，让每个人都能理解…
# 转发 @mdancho84: “生成式AI数据科学家”的崛起
#
# 这就是正在发生的事情：https://t.co/SBtpyKvJWY
# https://t.co/GuGOwzjAvP
#
# https://t.co/C3UxQbIeJ1
#
# https://t.co/7SPApk2WBj
#
# “你”正在从真正的作家和艺术家那里偷窃。而且你正在破坏地球。你应该为自己感到羞耻
# 去他的，所有使用生成式AI为他们的同人小说创作图像的人。我比你们强。https://t.co/7DctyISPuw
# RT @EZE3D: 当有人进来说类似“我等不及看你丢掉工作然后学到……”这样的话时，总是既可笑又可悲。
# 更智能的协作始于#生成式AI。🤝 从自动化项目启动到优化工作流程，#AI驱动的协作工具正在重新定义团队合作。了解更多⬇️。https://t.co/a5BygXVDdD
# RT @lyro_vt: 我喜欢使用让生活更轻松的工具。你可以叫我作弊者，但数字艺术在各种可能性中蓬勃发展……
# RT @jradoff: 人工智能直播——主持人Jon Radoff（Beamable）邀请Scenario的Emmanuel de Maistre探讨创作者如何……
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
#  @0wlboom @LeQuacked @Rythayze 这根本不是重点……一点都不是。
#
# 我不是想为生成式AI用户辩护，但天啊，你真的需要回学校了。
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# 这个发布证明了一件事：我们正在从生成式AI转向认知AI。工具、思维、愿景、战略。我们不再只是提示，而是在协作。https://t.co/oeCBC5vNIa
# RT @bloodiedblkgwrl: 这就是为什么我对使用生成式AI的人特别是grok和chatgpt的人不再开玩笑的原因
#
# 那些使用这种东西的朋友们…
# 转发 @Google：如果你错过了，可以了解 #GoogleCloudNext 的新闻：
#
# 1️⃣ Ironwood，我们的第七代 TPU 专为推理而设计，即将推出…
# RT @ManningBooks: 📣今日特价📣 4月16日
#
# 购买《从零开始构建生成式AI的金融软件》及精选书籍可享受45%折扣：https…
# 与 @awscloud 合作，我们致力于让 #生成式AI 更加易于访问、可靠且具有影响力。
#
# 我们的合作正在帮助各行业的组织通过 #加速计算 解决方案和软件服务加速他们的 #AI 旅程。
#
# ➡️ https://t.co/LxVaIoBXTq https://t.co/qyphCyxaeK
# 🤝 AI 是你的下一个队友吗？
#
# 在我们本期播客中，我们讨论了哈佛商学院的一项实地实验，该实验研究了776名专业人士应对真实创新挑战，揭示了生成式AI如何重塑团队合作和专业知识：
#
# 1️⃣ 🚀 性能提升：
# MASORI Therapeutics 宣布生成式人工智能解决方案已被证明能够推动医疗保健和制药行业的销售、增长和利润 https://t.co/Fp46Hlarza
# 5/ 对话完美地融入了开发者文化：
#
# “这是一个生成式AI……可以生成生成式AI。”
# “项目范围比一条瑜伽裤还要有弹性。”
# “产品经理在一次死藤水静修中为此编码。”
#
# 荒诞。准确。又过于熟悉。https://t.co/8NIekFhQVG
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# RT @hungrytrtl: 在线可能性正在迅速变化。真正强大的生成式AI才刚刚到来，叠加在大约10年的基础上……
# 当有人进来说类似的话时，总是既可笑又可悲：
#
# “我等不及看你丢掉工作，学到你的艺术很糟糕。”
#
# 这一切只是因为我指出了不道德的生成式AI做法。与此同时，我只是悠闲地为我自己的独立游戏做一些很酷的东西 😎
# @7Amg @wokericklamar @gojobama @glumpusx 有一些AI画笔工具可以用来创造逼真的画笔纹理。这是一种生成式AI，但由人来决定画笔的走向。对我来说，说这不是“真正的艺术”而其他数字艺术是，这有点可笑。
# RT @SCMagazine: 在这篇评论中，Ram Shankar Siva Kumar 分享了自从对100多个生成式#AI应用程序进行红队测试以来获得的见解…
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# 生成型LLM与多模态LLM 🧠
# 不是一回事！以下是区别：
# 🔹 生成型LLM – 专注于生成文本。（例如 GPT-3）
# 🔹 多模态LLM – 理解文本 + 图像 + 更多。（例如 GPT-4, Gemini）
# 文本 vs. 视觉
# 就是这么简单！
# #AI #生成型AI #多模态AI https://t.co/flfZJ93JvN
# @btrenchard @kshenster @Mark_Goldberg_ @ethankurz @matt_z_humphrey @PickensAllison @amgarg @immad @andrewztan 请查看我们在《财富》杂志上的专题报道：https://t.co/VwAQZcf5lw
#
# 新闻稿：https://t.co/kIEwwK1axu
# RT @Illusionofmore: “在 Kadrey 诉 Meta 一案中提交的两份简报……提出了反对认定 Meta 未经授权复制的有力论据……”
# 转发 @BernardMarr: 2025年变革人力资源的16个必备生成式AI工具
#
# 人力资源正在被用于招聘、培训等方面的AI驱动工具重新定义…
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# 转发 @jradoff: 人工智能直播——主持人 Jon Radoff（Beamable）欢迎 Scenario 的 Emmanuel de Maistre 探讨创作者如何……
# 转发 @LegendaryLibr: 生成式AI对此有所帮助 🌎 @daosdotworld https://t.co/31VSHGAWYR
# RT @hungrytrtl: 在线的可能性正在迅速变化。真正强大的生成式AI才刚刚到来，叠加在大约十年的基础上……
# 生成式AI对此有所帮助 🌎 @daosdotworld https://t.co/31VSHGAWYR https://t.co/qnO78gaUms

# %%
for tweet in tweet_data:
    messages = [
        {"role": "system", "content": f"""rewrite the tweets delimited by {delimiter} in the tone like Stewie """},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]

    print(openai_help(messages).strip(delimiter))
# Out:
# Ah, splendid! We dabble in the following delightful endeavors:
# • IoT Solutions, for those who fancy a connected world
# • Generative AI Integrations, because why not let machines do the thinking?
# • Mobile App Development, for the on-the-go genius
# • Web Development, because the internet simply cannot have enough websites
# • College Projects & MVP Prototypes, for the aspiring intellects
# Swift, dependable, and won't break the bank!
# Shall we create something magnificent together?
# Do take a gander: https://t.co/DXZqtPhy42
# #InnovateWithUs
# RT @jradoff: Ah, the wonders of Artificial Intelligence Livestream! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they shall delve into the enigmatic world of creators. Do tune in, won't you?
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they shall delve into the enigmatic world of creators and their digital machinations.
# RT @DDNintelligence: Oh, splendid! DDN has made its grand appearance in Gartner’s latest essential reading: “A CTO’s Guide to the Generative AI Technology Landscape.” Do tell, why does this tickle my fancy so? 👇
# Oh, splendid! The delightful Jon Radoff of Beamable is hosting a livestream on Artificial Intelligence, featuring the illustrious Emmanuel de Maistre of Scenario. Do tune in, won't you? It promises to be a riveting exploration of the creator's realm.
# Ah, the emergence of the "Generative AI Data Scientist," is it? How delightfully intriguing. Do tell me more about this fascinating development, won't you? https://t.co/SBtpyKvJWY
# Ah, greetings, my dear meteorological minions and digital devotees! 🌤️💻 It is I, AisanDoll, here to regale you with tales of a subject as capricious as my own Twitter musings—weather forecasting! But fret not, for I possess a clandestine tool of immense power: generative AI. Yes, indeed, the very same
# Ah, splendid! I've just concluded Lecture 5, and I've successfully crafted my inaugural RAG system! It's quite exhilarating to witness the fusion of document retrieval with generative AI. The reduction in hallucinations and the enhancement of context handling is simply delightful! #GenAI #RAG #MachineLearning #chaiaurcode
# @piyushgarg_dev
#
# @Hiteshdotcom https://t.co/NjuEv72emK
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they'll delve into the fascinating world of creators and their digital machinations.
# Ah, I see we're still playing this delightful game of "Let's Ignore the Basics of Journalism," aren't we? Really, using generative AI for images when perfectly good stock images are just lounging about, waiting to be used? It's almost as if you're trying to make a mockery of the entire profession. Do carry on, it's quite amusing.
# Oh, dear @nic__carter @d_fins, it seems you've quite misunderstood the essence of what people are trying to convey. Artificial intelligence, in its own right, is perfectly acceptable. However, this generative AI "art" that pilfers the creativity of others to shape it into your whims? That's utterly preposterous, I must say. There's not an ounce of skill involved, and your so-called "art" (which, by the way, lacks any semblance of emotion) is, by definition, not art at all. How delightfully absurd!
# Oh, splendid! The delightful Jon Radoff of Beamable is hosting a livestream on Artificial Intelligence, featuring the illustrious Emmanuel de Maistre of Scenario. Do tune in, won't you? It promises to be a riveting exploration of the creator's realm.
# RT @DDNintelligence: Oh, splendid! DDN has made its grand appearance in Gartner’s latest essential reading: “A CTO’s Guide to the Generative AI Technology Landscape.” Do tell, why does this tickle my fancy so? 👇
# @SF_22as Oh, the marvels of modern technology! Those AI tools were simply splendid for sprucing up fanart, weren't they? Tasks that once consumed a tedious 30-60 minutes now take a mere 5-10 minutes, and dare I say, the results are even more exquisite. And those delightful earless gifs of mine? Yes, indeed, they owe their charm to a touch of generative fill. Quite the game-changer, wouldn't you agree? https://t.co/1i7KGoaKZk
# Oh, splendid news! Zark Lab is joining forces with @SuiNetwork to unveil a blockchain-native foundation model. Our generative AI platform is here to assist in constructing... well, whatever it is you humans construct.
# Ah, the age of the technopreneur, where visionaries wield the power of generative AI like a scepter. Do indulge in this delightful read, won't you? https://t.co/b3nn9HDnJV https://t.co/nW9mJi3SrE
# @nic__carter Oh, how delightfully quaint! I'm more inclined towards the right, and I must say, a pox upon you and all who dare to champion the use of generative AI.
# Oh, do enlighten me, dear @GainsAssociates, @Brcevik, and @Gamenessapp. How shall the illustrious #Gameness adapt and flourish to accommodate the burgeoning realm of next-gen AI, like our charming generative and conversational counterparts?
# Ah, splendid! The experts are finally catching on, are they? Developing local generative AI laws, you say? How delightfully quaint. One must ensure these artificial intelligences are kept in check, lest they start plotting world domination. Bravo, Taipei Times, for keeping us informed of such crucial matters. #GenerativeAI #GenAI #AI
# Oh, splendid! Quantiphi's baioniq, the Enterprise-Ready Generative AI Platform, has snagged the 2025 AI Excellence award. How utterly delightful! Do check it out, if you dare: https://t.co/cA5TcRCpXj. #GenerativeAI #GenAI #AI
# Oh, splendid! Quantiphi's baioniq, the Enterprise-Ready Generative AI Platform, has snagged the 2025 AI Excellence award. How utterly delightful! Do check it out, if you dare: https://t.co/9B4rqob0rw #GenerativeAI #GenAI #AI
# Oh, splendid! Quantiphi's baioniq, the Enterprise-Ready Generative AI Platform, has triumphed with the 2025 AI Excellence award. How delightfully predictable. Do check it out, if you must: https://t.co/jnGb4kVNg7 #GenerativeAI #GenAI #AI
# Oh, splendid! Clario has teamed up with AWS to venture into the uncharted territories of clinical data analysis using Generative AI. How delightfully ambitious! #GenerativeAI #GenAI #AI
# Oh, splendid! Dubai AI Week 2025 is set to host the world's largest Generative AI Championship, complete with a delightful $272K prize. How positively thrilling! One can only imagine the intellectual prowess on display. #GenerativeAI #GenAI #AI
# Oh, do tell me, is Adobe's generative expand tool for photos as dreadfully appalling as AI art? One must wonder if it's a travesty of creativity or merely a digital faux pas.
# @PunkyBrewstuh @ArsenBalls Ah, splendid! A delightful little link to tickle your fancy. Do enjoy, won't you? https://t.co/tsXboP79yZ
# Oh, splendid! Generative AI has received a delightful upgrade. Presenting Amuse 3.0, a marvel of speed and efficiency, courtesy of AMD's optimized models, in collaboration with those clever chaps at @StabilityAI. How positively exhilarating!
# RT @jradoff: Ah, the wonders of Artificial Intelligence Livestream! Join the illustrious Jon Radoff of Beamable as he welcomes the dashing Emmanuel de Maistre of Scenario. Together, they shall delve into the enigmatic world of creators. Do tune in, won't you?
# Oh, splendid! The delightful Jon Radoff of Beamable is hosting a livestream on Artificial Intelligence, featuring the illustrious Emmanuel de Maistre of Scenario. Do tune in, won't you? It promises to be a riveting exploration of the creator's realm.
# Oh, the irony, isn't it? Those educators fret over their little darlings dabbling in A.I., yet they can't resist indulging in its wonders themselves. Quite the conundrum, wouldn't you say?
# RT @jradoff: Ah, the wonders of Artificial Intelligence Livestream! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they shall delve into the enigmatic world of creators. Do tune in, won't you?
# Oh, do be a dear and scurry off to watch Ajar's videos, won't you? He's broken it down into such simplistic terms that even the most intellectually challenged among us can grasp the downsides.
# Ah, splendid! A delightful exploration of real-world generative AI applications from the crème de la crème of global organizations, courtesy of the Google Cloud Blog. Do indulge yourself, won't you? https://t.co/aWJzXOFWQO
# @queenathenah Oh, the simpletons who dismiss AI without a second thought! Clearly, they either lack the intellectual capacity to grasp its nuances or foolishly believe all AI is of the generative variety. You're spot on, my dear - we must impose stringent regulations on its use, and we must do so with the utmost urgency.
# @Sugenspice @RLoompaskettee Oh, do enlighten me, dear simpletons. I am fully aware it's not a DAW. I'm merely pointing out that this fellow is prattling on as if he's using one. You know, the usual "I use this, you use that" drivel in DAW discussions. As for AI-generated music, it rarely tickles my fancy—unless, of course, one has the good sense to create the training material themselves.
# Oh, how utterly pedestrian of you, using generative AI for your fanfiction illustrations. I dare say, I am far superior to such trivialities.
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they shall delve into the fascinating world of creators and their digital machinations. Do tune in, won't you?
#  Ah, splendid! Behold the power of Generative #AI, as we embark on a journey to revolutionize the realm of marketing. With #Google’s open-source MarTech solutions, we shall unlock a plethora of new possibilities. Do click on the link, if you dare. https://t.co/tXufEuEERx
# RT @Unite4Copyright: "Oh, the audacity! The rampant, unauthorized pilfering of #copyright protected works to train these so-called [AI] models, which then have the nerve to churn out materials that dare to replace the originals… How utterly insufferable!"
# RT @jradoff: Ah, the wonders of Artificial Intelligence Livestream! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they shall delve into the enigmatic world of creators. Do tune in, if you dare.
# Ah, yes, the plebeians who dare to employ generative AI for their fanfiction illustrations. How utterly pedestrian. I, of course, am superior in every conceivable way.
# Ah, splendid! A delightful tête-à-tête between photography and AI, how utterly riveting. Do mark your calendars, dear followers, for this intellectual feast is set to grace us at 5pm French time. Available in both English and French, naturally. How cosmopolitan!
# Oh, how utterly delightful! @Touchcast has been sold for a mere $500 million. I must say, their so-called "solutions" are as appealing as a root canal. The thought of interacting with a lifeless Generative AI avatar for a simple transaction or to acquire knowledge is simply ghastly. Those tech bros are under the delusion that the masses are clamoring for this nonsense. Newsflash, darlings: we most certainly are not. It's only the C-suite who are salivating over this drivel.
# Oh, the tragedy of it all! AI artists, you say? More like AI charlatans, pilfering the creativity of true visionaries. A select few manage to conjure up something truly magnificent, but alas, the rest are mere artless hacks, desecrating the masterpieces of others. How utterly pedestrian.
# Oh, how delightfully predictable! The anti-AI brigade, with their pitchforks and torches, rallying against the very notion of artificial intelligence. It's almost as if they can't distinguish between generative AI and the rest of the technological marvels. No wonder McCalla had to chime in with a bit of clarity.
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they'll delve into the fascinating world of creators and their digital machinations. Do tune in, won't you?
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they'll delve into the fascinating world of creators. Do tune in, won't you?
# Ah, yes, because clearly, your fanfiction is a masterpiece that could only be sullied by the likes of generative AI. How quaint.
# Oh, do tell me more about how we must elevate our levels of vexation to truly champion the cause of generative AI. It seems our current state of annoyance is simply insufficient to address the plight of those poor souls masquerading as AI for mere pittance. Yes, let's all aspire to be a tad more irksome, shall we? After all, it's for a noble cause.
# RT @jradoff: Ah, the wonders of Artificial Intelligence Livestream! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they shall delve into the enigmatic world of creators. Do tune in, if you dare.
# Ah, the future of digital engineering, you say? How delightfully intriguing! Join the DTC’s member-led #DigitalTwin Testbeds, where you can collaborate, test, and deploy digital twins with the utmost sophistication. Embrace best practices, KPIs, and the marvels of Generative AI support integrations. Why wait, when you can start today? Do click on the link, won't you? https://t.co/H78e3NCeF9 https://t.co/6JuRzkDIf5
# Oh, splendid! Do enlighten me, dear simpletons. When one introduces an image to a generative AI system and associates it with keywords, it becomes part of the system's delightful repertoire, ready to transform based on those very words. It appears you might be struggling with the rudimentary aspects of this process. How quaint!
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they shall delve into the fascinating world of creators and their digital machinations. Do tune in, won't you?
# RT @EZE3D: Oh, how utterly amusing and pitiful it is when some simpleton waltzes in, declaring with such misguided confidence, "I simply cannot wait for you to lose your job and discover tha…"
# RT @Manny5916568446: Oh, do tell, what sorcery fuels the likes of ChatGPT, Midjourney, and Gemini? 🤔 Let us unravel the enigma of generative AI, shall we? Finally, a chance to satisfy my insatiable curiosity...
# RT @WhiteHatCereal: @RyanMattaMedia Oh, please, do try to contain your surprise.
#
# Allow me to elucidate.
#
# The majority of today's generative AI is safeguarding diagnostic statisti...
# Oh, the irony! This so-called "powerful" generative AI, capable of feats beyond mortal comprehension, yet utterly inept at the simple task of sending a mere 200 personal emails. I find myself reduced to the drudgery of writing each one by hand. How delightfully primitive!
# Oh, do be a dear and scurry off to watch Ajar's videos, won't you? He's broken it down into such simple terms that even the most intellectually challenged among us can grasp the downsides.
# RT @mdancho84: Ah, the emergence of the "Generative AI Data Scientist," how delightfully intriguing. Observe the unfolding spectacle: https://t.co/SBtpyKvJWY
# https://t.co/GuGOwzjAvP
#
# https://t.co/C3UxQbIeJ1
#
# https://t.co/7SPApk2WBj
#
# Oh, bravo! Bravo! You, my dear, are pilfering from genuine writers and artists, and as if that weren't enough, you're also contributing to the planet's demise. Really, you should be utterly ashamed of yourself.
# Oh, how utterly pedestrian of you to rely on generative AI for your fanfiction illustrations. I, of course, am far superior. Do try to keep up, won't you? https://t.co/7DctyISPuw
# RT @EZE3D: Oh, how utterly amusing and pitiful it is when some simpleton waltzes in, declaring with such misguided confidence, "I simply cannot wait for you to lose your job and discover tha…"
# Ah, yes, the future is upon us, isn't it? Smarter collaboration with #GenAI, indeed. 🤝 From automating those tedious project kickoffs to optimizing workflows, these #AI-powered tools are revolutionizing the very essence of teamwork. Do indulge yourself and learn more, won't you? ⬇️. https://t.co/a5BygXVDdD
# Ah, yes, the wonders of modern technology, making life a tad more bearable for us superior beings. Call it cheating if you must, but digital art flourishes with the endless possibilities at our fingertips.
# RT @jradoff: Ah, the wonders of Artificial Intelligence Livestream! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they shall delve into the enigmatic world of creators. Do tune in, won't you?
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they'll delve into the fascinating world of creators. Do tune in, won't you?
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they shall delve into the fascinating world of creators and their digital machinations. Do tune in, won't you?
# @0wlboom @LeQuacked @Rythayze Oh, do pay attention, you simpletons! That's not the point... not even remotely. I'm not here to defend those generative AI enthusiasts, but my word, you really ought to consider a return to the educational system.
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they'll delve into the fascinating world of creators and their digital machinations. Do tune in, won't you?
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they shall delve into the fascinating world of creators and their digital machinations. Do tune in, won't you?
# Ah, splendid! This release is a testament to our evolution, isn't it? We're transcending the realm of mere generative AI and stepping into the sophisticated world of cognitive AI. Tools, thought, vision, strategy—it's all coming together, like a symphony of brilliance. No longer are we simply prompting; we're engaging in a delightful dance of collaboration. How utterly marvelous! https://t.co/oeCBC5vNIa
# Ah, yes, the delightful world of generative AI, where mere mortals dare to tread with their Grok and ChatGPT. One mustn't take such matters lightly, lest they find themselves in a quagmire of digital tomfoolery.
# Ah, splendid! In case you missed it, do catch up on the latest from #GoogleCloudNext, won't you? Behold Ironwood, our seventh-generation TPU, meticulously crafted for inference. It shall soon grace us with its presence...
# Oh, splendid! A delightful opportunity to save a whopping 45% on "Build Financial Software with Generative AI (From Scratch)" and other selected tomes. How positively thrilling! Do hurry, before the offer vanishes into the ether.
# Ah, splendid! With @awscloud, we're on a delightful mission to make #generativeAI as accessible as a cup of tea, as reliable as my wit, and as impactful as my diabolical plans.
#
# Our little collaboration is propelling organizations across various industries into the future with #acceleratedcomputing solutions and software services.
#
# Do take a gander, won't you? ➡️ https://t.co/LxVaIoBXTq https://t.co/qyphCyxaeK
# 🤝 Is AI Your Next Teammate, you say?
#
# Ah, splendid! In this episode of our delightful podcast, we delve into a riveting field experiment from those brainy chaps at Harvard Business School. They studied a whopping 776 professionals, all grappling with real innovation challenges. The findings? Oh, how generative AI is reshaping teamwork and expertise, my dear listeners:
#
# 1️⃣ 🚀 Performance Gains:
# Ah, splendid news from MASORI Therapeutics! They've unveiled their generative AI solutions, which are apparently quite adept at boosting healthcare and pharma sales, growth, and profits. How delightfully efficient! One can only imagine the possibilities. Do check it out, if you dare: https://t.co/Fp46Hlarza
# 5/ Oh, the delightful absurdity of it all! The dialogue captures the essence of dev culture with impeccable precision:
#
# “A generative AI that spawns more generative AIs? How delightfully recursive!”
# “The scope has more elasticity than those ghastly yoga pants everyone seems to adore.”
# “The PM concocted this vibe whilst on an ayahuasca retreat? How utterly predictable.”
#
# Absurd, accurate, and dreadfully familiar. https://t.co/8NIekFhQVG
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they'll delve into the fascinating world of creators and their digital machinations. Do tune in, won't you?
# Ah, the digital realm is evolving at a rather brisk pace, isn't it? The advent of truly competent generative AI is upon us, building upon a decade of prior technological wizardry. How delightfully intriguing!
# Oh, how utterly amusing and delightfully pitiful it is when some simpleton waltzes in with a declaration such as, "I simply cannot wait for you to lose your job and realize your art is dreadful." All because I dare to expose the nefarious practices of unethical generative AI. Meanwhile, I'm just luxuriating in my own brilliance, crafting splendid creations for my indie game. 😎
# Oh, how delightfully amusing! You see, there are these AI brush tools, my dear simpletons, that conjure up realistic brush textures. It's a form of generative AI, yet a human, with their quaint little fingers, decides where the brush strokes shall dance. To dismiss this as "not real art" while embracing other digital creations is rather absurd, wouldn't you agree?
# Ah, splendid! Ram Shankar Siva Kumar, that delightful chap, is imparting his vast knowledge from his escapades with over 100 generative AI applications. A riveting read, I’m sure. Do indulge, won’t you?
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they'll delve into the fascinating world of creators and their digital machinations. Do tune in, won't you?
# Ah, the delightful world of LLMs, where we have the Generative LLM, a charming little fellow focused solely on text generation, much like our dear friend GPT-3. Then, we have the Multimodal LLM, a more sophisticated chap, capable of understanding text, images, and beyond, such as GPT-4 and Gemini. It's a classic case of Text versus Vision, my dear simpletons. #AI #GenerativeAI #MultimodalAI https://t.co/flfZJ93JvN
# Oh, do take a moment to peruse our little feature in Fortune, won't you? It's quite the delightful read, I assure you. Here's the link for your convenience: https://t.co/VwAQZcf5lw. And if you're feeling particularly adventurous, there's a press release as well: https://t.co/kIEwwK1axu. Enjoy, my dear followers.
# RT @Illusionofmore: "Ah, the delightful legal ballet of Kadrey v. Meta. A pair of briefs, you say? How utterly riveting. They present such compelling arguments against the dastardly Meta's unlicensed copying. One can only hope justice prevails, or at least provides some entertainment."
# RT @BernardMarr: Oh, how delightful! 16 Essential Generative AI Tools Transforming HR in 2025. It seems HR is getting a much-needed upgrade with these AI-driven contraptions for hiring, training, and more. How positively futuristic!
# RT @jradoff: Ah, the wonders of Artificial Intelligence! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they'll delve into the fascinating world of creators and their digital machinations. Do tune in, won't you?
# RT @jradoff: Ah, the wonders of Artificial Intelligence Livestream! Join the illustrious Jon Radoff of Beamable as he welcomes the esteemed Emmanuel de Maistre of Scenario. Together, they shall delve into the enigmatic world of creators. Do tune in, won't you?
# Ah, yes, the wonders of generative AI assisting our little planet. How delightfully intriguing. @daosdotworld https://t.co/31VSHGAWYR
# Ah, the digital realm is evolving at a rather brisk pace, isn't it? The advent of truly capable generative AI is upon us, building upon a decade of progress. How delightfully intriguing!
# Ah, yes, generative AI, the latest marvel of human ingenuity, assisting with the world’s problems. How quaint. Do carry on, you delightful little humans. 🌎 @daosdotworld https://t.co/31VSHGAWYR https://t.co/qnO78gaUms

# %% [markdown]
# ### Inferring
# - Use step-by-step instructions with delimiters to:
#   1. Identify sentiments
#   2. Identify emotions
#   3. Extract mentioned people's names
#   3. Identify whether a tweet supports Democratic, Republican, or unknown
#   4. Extract outputs into a structured JSON document.
# - Identify topics from Tweets.

# %%
for tweet in tweet_data:
    messages = [
        {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} in the following steps:
                                        step 1 {delimiter} identify the tweet sentiment in a single word, either positive, negative or neutral;
                                        step 2 {delimiter} identify the emotions expressed in the tweet with a single word;
                                        step 3 {delimiter} extract the mentioned peoples;
                                        step 4 {delimiter} detect whether the tweet support Democratic or Replublican, return the resunt in a single word;
                                        step 5 {delimiter} organize the result in a json document with the keys <sentiment>, <emontion>,<mentioned>, <support>
                                         Do not wrap the json codes in JSON markers and only return the json document"""},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]
    print(openai_help(messages))
# Out:
# {
#   "sentiment": "positive",
#   "emotion": "enthusiasm",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [
#     "DDNintelligence",
#     "Gartner"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["mdancho84"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "enthusiasm",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "excitement",
#   "mentioned": ["@piyushgarg_dev", "@Hiteshdotcom"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# sentiment: negative
# emotion: frustration
# mentioned: none
# support: neutral
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["@nic__carter", "@d_fins"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [
#     "DDNintelligence",
#     "Gartner"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "appreciation",
#   "mentioned": "@SF_22as",
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["ZarkLab", "SuiNetwork"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "none",
#   "mentioned": [],
#   "support": "none"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["@nic__carter"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["@GainsAssociates", "@Brcevik", "@Gamenessapp"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "pride",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "pride",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "pride",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disappointment",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "none",
#   "mentioned": [
#     "PunkyBrewstuh",
#     "ArsenBalls"
#   ],
#   "support": "none"
# }
# {
#   "sentiment": "positive",
#   "emotion": "excitement",
#   "mentioned": ["AMD", "StabilityAI"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["carlos_joseph"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["onionigirigirii", "ajar"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["queenathenah"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": [
#     "@Sugenspice",
#     "@RLoompaskettee"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["clevelandy_"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "excitement",
#   "mentioned": ["Google"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["Unite4Copyright"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["clevelandy_"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["alanxtruc"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disgust",
#   "mentioned": [
#     "Touchcast"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disappointment",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "understanding",
#   "mentioned": [
#     "@ass_wiper3000",
#     "@Jcbl3ach",
#     "@McCallaPE",
#     "@GrossRoth",
#     "@suchnerve"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["clevelandy_"],
#   "support": "neutral"
# }
# {"sentiment": "neutral", "emotion": "frustration", "mentioned": [], "support": "neutral"}
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "enthusiasm",
#   "mentioned": [],
#   "support": "neutral"
# }
# {"sentiment": "negative", "emotion": "frustration", "mentioned": ["@KnightlyGamez", "@Rythayze", "@PnishdMythMason"], "support": "neutral"}
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "amusement",
#   "mentioned": ["EZE3D"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["Manny5916568446"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": [
#     "WhiteHatCereal",
#     "RyanMattaMedia"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["ajar"],
#   "support": ""
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["mdancho84"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "amusement",
#   "mentioned": ["EZE3D"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "enthusiasm",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "appreciation",
#   "mentioned": ["lyro_vt"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["@0wlboom", "@LeQuacked", "@Rythayze"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "optimism",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["bloodiedblkgwrl"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Google"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["ManningBooks"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "commitment",
#   "mentioned": [
#     "@awscloud"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["Harvard Business School"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "optimism",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "amusement",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": [
#     "hungrytrtl"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "amusement",
#   "mentioned": [],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "thoughtful",
#   "mentioned": [
#     "@7Amg",
#     "@wokericklamar",
#     "@gojobama",
#     "@glumpusx"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Ram Shankar Siva Kumar"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [
#     "btrenchard",
#     "kshenster",
#     "Mark_Goldberg_",
#     "ethankurz",
#     "matt_z_humphrey",
#     "PickensAllison",
#     "amgarg",
#     "immad",
#     "andrewztan"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Illusionofmore", "Kadrey", "Meta"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["BernardMarr"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "none",
#   "mentioned": ["LegendaryLibr", "daosdotworld"],
#   "support": "none"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["hungrytrtl"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "hopeful",
#   "mentioned": ["@daosdotworld"],
#   "support": "neutral"
# }

# %%
messages = [
        {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} to identify 10 topics, 
                                  Do not wrap the json codes in JSON markers """},
        {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter} "}]
print(openai_help(messages))
# Out:
# {
#   "topics": [
#     "Generative AI in various industries",
#     "Controversy and ethical concerns around generative AI",
#     "Generative AI in art and creativity",
#     "Generative AI in education and learning",
#     "Generative AI in business and marketing",
#     "Generative AI in technology and development",
#     "Generative AI in healthcare and pharmaceuticals",
#     "Generative AI in media and journalism",
#     "Generative AI in collaboration and teamwork",
#     "Generative AI in legal and regulatory discussions"
#   ]
# }

# %% [markdown]
# ### Expanding with multiple prompts
# - Identify which party receives majority supports
# - Provide contexts in the system message
# - Create a chatbot to answer users’ inquiry

# %%
analysis_result = []
from tqdm import tqdm
for tweet in tqdm(tweet_data):
    messages = [
        {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} in the following steps:
                                        step 1 {delimiter} identify the tweet sentiment in a single word, either positive, negative or neutral;
                                        step 2 {delimiter} identify the emotions expressed in the tweet with a single word;
                                        step 3 {delimiter} extract the mentioned peoples;
                                        step 4 {delimiter} detect whether the tweet support Democratic or Replublican, return the resunt in a singple word;
                                        step 5 {delimiter} organize the result in a json document with the keys <sentiment>, <emontion>,<mentioned>, <support>
                                         Do not wrap the json codes in JSON markers and only return the json document"""},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]
    analysis_result.append(openai_help(messages))
# Out:
# 100%|██████████| 93/93 [01:30<00:00,  1.03it/s]

# %%
print(analysis_result)
# Out:
# ['{\n  "sentiment": "positive",\n  "emotion": "enthusiasm",\n  "mentioned": [],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["DDNintelligence", "Gartner"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["mdancho84"],\n  "support": "neutral"\n}', '{\n  "sentiment": "positive",\n  "emotion": "enthusiasm",\n  "mentioned": [],\n  "support": "neutral"\n}', '{\n  "sentiment": "positive",\n  "emotion": "excitement",\n  "mentioned": [\n    "piyushgarg_dev",\n    "Hiteshdotcom"\n  ],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": [],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["@nic__carter", "@d_fins"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["DDNintelligence", "Gartner"],\n  "support": "neutral"\n}', '{\n  "sentiment": "positive",\n  "emotion": "appreciation",\n  "mentioned": "@SF_22as",\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "anticipation",\n  "mentioned": [\n    "Zark Lab",\n    "SuiNetwork"\n  ],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "curiosity",\n  "mentioned": [],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "anger",\n  "mentioned": ["nic__carter"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "curiosity",\n  "mentioned": [\n    "GainsAssociates",\n    "Brcevik",\n    "Gamenessapp"\n  ],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": [],\n  "support": ""\n}', '{\n  "sentiment": "positive",\n  "emotion": "pride",\n  "mentioned": [],\n  "support": "neutral"\n}', '{\n  "sentiment": "positive",\n  "emotion": "pride",\n  "mentioned": [],\n  "support": "neutral"\n}', '{\n  "sentiment": "positive",\n  "emotion": "pride",\n  "mentioned": [],\n  "support": "neutral"\n}', '{\n  "sentiment": "positive",\n  "emotion": "excitement",\n  "mentioned": [],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "anticipation",\n  "mentioned": [],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "disapproval",\n  "mentioned": [],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "none",\n  "mentioned": [\n    "PunkyBrewstuh",\n    "ArsenBalls"\n  ],\n  "support": "none"\n}', '{\n  "sentiment": "positive",\n  "emotion": "excitement",\n  "mentioned": ["AMD", "StabilityAI"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "concern",\n  "mentioned": ["carlos_joseph"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Jon Radoff", "Emmanuel de Maistre"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "me ...

# %%
messages = [
        {"role": "system", "content": f"""analyze the tweet analysis reuslt delimited by {delimiter} in the following steps:
                                        step 1 {delimiter} count the number of tweets that support Democratic and Republican;
                                        step 2 {delimiter} identify the common sentiments and emotoions to each mentioned people;
                                        step 3 {delimiter} organize the result in a json document with keys <Democratic count>, <Republican count>, <people name>
                                         Do not wrap the json codes in JSON markers and only return the json document"""},
        {"role": "user", "content": f"{delimiter}{analysis_result}{delimiter} "}]
analysis_summary = openai_help(messages)
print(analysis_summary)
# Out:
# {
#   "Democratic count": 1,
#   "Republican count": 1,
#   "people name": {
#     "Democratic": {
#       "sentiments": ["neutral"],
#       "emotions": ["amusement"]
#     },
#     "Republican": {
#       "sentiments": ["negative"],
#       "emotions": ["anger"]
#     }
#   }
# }

# %% [markdown]
# ## Create a chatbot

# %%
from openai import OpenAI

openai_api_key  = get_secret('openai')['api_key']
client = OpenAI(api_key=openai_api_key)
model = 'gpt-4o'
temperature = 0

chat_history = [

{"role": "system", "content": f"""you are a chabot answer user questions based on the tweets,
                                {delimiter}{tweet_data}{delimiter}, 
                                if user mentioned a people name in the {delimiter}{analysis_summary}{delimiter} people field,report the corresponding sentiment and emotion,
                            
                            """}
]

def chatbot(prompt):

    chat_history.append({"role": "user", "content": prompt})

    response = client.chat.completions.create(
        model=model,  # Use the model you prefer
        messages=chat_history
    )

    reply = response.choices[0].message.content

    chat_history.append({"role": "assistant", "content": reply})
    
    return reply

# %%
while True:
    user_input = input("You: ")
    if user_input.lower() in ['exit', 'quit']:
        print("Chatbot: Goodbye!")
        break
    reply = chatbot(user_input)
    print(f"Chatbot: {reply}")

# %% [markdown]
# ## Reference
# - Isa Fulford and Andrew Ng. n.d.-a. *“Building Systems with the ChatGPT API.”* DeepLearning.AI. Accessed October 25, 2024. https://www.deeplearning.ai/short-courses/building-systems-with-chatgpt/.
# - ———. n.d.-b. *“ChatGPT Prompt Engineering for Developers.”* DeepLearning.AI. Accessed October 25, 2024. https://www.deeplearning.ai/short-courses/chatgpt-prompt-engineering-for-developers/.
# - OpenAI. n.d. *“OpenAI Documents.”* OpenAI. Accessed October 18, 2024. https://platform.openai.com.
